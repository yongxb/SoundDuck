# %% [markdown]
# ## Pandas Dataframe

# %%
import pandas as pd
data = pd.read_csv("../data/csv/my_data.csv")
data.head()
# Out:
#        id     gen       sp  ssp  group               en            rec
# 0  794616  Tringa  totanus  NaN  birds  Common Redshank   Hannu Varkki  \
# 1  794247  Tringa  totanus  NaN  birds  Common Redshank  Ricardo Hevia
# 2  793904  Tringa  totanus  NaN  birds  Common Redshank  James Spencer
# 3  793224  Tringa  totanus  NaN  birds  Common Redshank  Simon Elliott
# 4  792814  Tringa  totanus  NaN  birds  Common Redshank  Julien Piette
#
#               cnt                                                loc      lat
# 0         Finland                     Östersundom, Helsinki, Uusimaa  60.2433  \
# 1           Spain          Ortegal (near  Cariño), A Coruña, Galicia  43.7412
# 2  United Kingdom  Great Britain (near  Nafferton), East Riding o...  54.0113
# 3  United Kingdom                   Boulmer, Northumberland, England  55.4241
# 4          France                   Dunkerque, Nord, Hauts-de-France  51.0445
#
#    ...              mic    smp
# 0  ...  Sennheiser ME66  48000  \
# 1  ...              NaN  44100
# 2  ...          Inbuilt  44100
# 3  ...         MKH60/30  44100
# 4  ...              NaN  44100
#
#                                           sono.small
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/ff...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/ff...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/ff...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/ff...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/ff...
#
#                                             sono.med
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/ff...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/ff...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/ff...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/ff...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/ff...
#
#                                           sono.large
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/ff...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/ff...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/ff...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/ff...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/ff...
#
#                                            sono.full
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/ff...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/ff...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/ff...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/ff...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/ff...
#
#                                           osci.small
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/wa...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/wa...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/wa...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/wa...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/wa...
#
#                                             osci.med
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/wa...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/wa...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/wa...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/wa...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/wa...
#
#                                           osci.large
# 0  //xeno-canto.org/sounds/uploaded/XDCPMYMSWN/wa...  \
# 1  //xeno-canto.org/sounds/uploaded/BQFSTZRSEP/wa...
# 2  //xeno-canto.org/sounds/uploaded/HUEOQCQSKZ/wa...
# 3  //xeno-canto.org/sounds/uploaded/FFFADKCCII/wa...
# 4  //xeno-canto.org/sounds/uploaded/AEYBSAOVGN/wa...
#
#                                            file-path
# 0  data/audio/XC794616_TRITOT_2023_04_20_10_31_TO...
# 1                 data/audio/XC794247_ZOOM0001to.wav
# 2  data/audio/XC793904_Redshank_2121_160423_filte...
# 3             data/audio/XC793224_RK_HD389B_1.50.wav
# 4  data/audio/XC792814_230409_gambette_type_chant...
#
# [5 rows x 44 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 44 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1705 non-null   int64
#  1   gen            1705 non-null   object
#  2   sp             1705 non-null   object
#  3   ssp            162 non-null    object
#  4   group          1705 non-null   object
#  5   en             1705 non-null   object
#  6   rec            1705 non-null   object
#  7   cnt            1705 non-null   object
#  8   loc            1704 non-null   object
#  9   lat            1694 non-null   float64
#  10  lng            1694 non-null   float64
#  11  alt            1661 non-null   object
#  12  type           1691 non-null   object
#  13  sex            293 non-null    object
#  14  stage          259 non-null    object
#  15  method         1705 non-null   object
#  16  url            1705 non-null   object
#  17  file           1705 non-null   object
#  18  file-name      1705 non-null   object
#  19  lic            1705 non-null   object
#  20  q              1705 non-null   object
#  21  length         1705 non-null   object
#  22  time           1705 non-null   object
#  23  date           1705 non-null   object
#  24  uploaded       1705 non-null   object
#  25  also           1705 non-null   object
#  26  rmk            780 non-null    object
#  27  bird-seen      1705 non-null   object
#  28  animal-seen    1705 non-null   object
#  29  playback-used  1705 non-null   object
#  30  temp           0 non-null      float64
#  31  regnr          0 non-null      float64
#  32  auto           1705 non-null   object
#  33  dvc            108 non-null    object
#  34  mic            69 non-null     object
#  35  smp            1705 non-null   int64
#  36  sono.small     1705 non-null   object
#  37  sono.med       1705 non-null   object
#  38  sono.large     1705 non-null   object
#  39  sono.full      1705 non-null   object
#  40  osci.small     1705 non-null   object
#  41  osci.med       1705 non-null   object
#  42  osci.large     1705 non-null   object
#  43  file-path      1705 non-null   object
# dtypes: float64(4), int64(2), object(38)
# memory usage: 586.2+ KB

# %%
data["file-path"].nunique()
# Out:
# 1704

# %% [markdown]
# |**Columns**|**Description**|
# |:---:|:---:|
# | id |  the catalogue number of the recording on xeno-canto |
# | gen |  the generic name of the species |
# | sp |  the specific name (epithet) of the species |
# | ssp |  the subspecies name (subspecific epithet) |
# | group |  the group to which the species belongs (birds, grasshoppers) |
# | en |  the English name of the species |
# | rec |  the name of the recordist |
# | cnt |  the country where the recording was made |
# | loc |  the name of the locality |
# | lat |  the latitude of the recording in decimal coordinates |
# | lng |  the longitude of the recording in decimal coordinates |
# | type |  the sound type of the recording (combining both predefined terms such as 'call' or 'song' and additional free text options) |
# | sex |  the sex of the animal |
# | stage |  the life stage of the animal (adult, juvenile, etc.) |
# | method |  the recording method (field recording, in the hand, etc.) |
# | url |  the URL specifying the details of this recording |
# | file |  the URL to the audio file |
# | file-name |  the original file name of the audio file |
# | sono |  an object with the urls to the four versions of sonograms |
# | osci |  an object with the urls to the three versions of oscillograms |
# | lic |  the URL describing the license of this recording |
# | q |  the current quality rating for the recording |
# | length |  the length of the recording in minutes |
# | time |  the time of day that the recording was made |
# | date |  the date that the recording was made |
# | uploaded |  the date that the recording was uploaded to xeno-canto |
# | also |  an array with the identified background species in the recording |
# | rmk |  additional remarks by the recordist |
# | bird-seen |  despite the field name (which was kept to ensure backwards compatibility), this field indicates whether the recorded animal was seen |
# | animal-seen |  was the recorded animal seen? |
# | playback-used |  was playback used to lure the animal? |
# | temperature |  temperature during recording (applicable to specific groups only) |
# | regnr |  registration number of specimen (when collected) |
# | auto |  automatic (non-supervised) recording? |
# | dvc |  recording device used |
# | mic |  microphone used |
# | smp |  sample rate |

# %%
data.hist(figsize=(15,15));

# %%
data["en"].value_counts().plot(kind="bar");

# %%
data.nunique()
# Out:
# id               1705
# gen                 3
# sp                  3
# ssp                24
# group               1
# en                  3
# rec               412
# cnt                55
# loc               823
# lat               877
# lng               879
# alt                89
# type               89
# sex                 6
# stage               5
# method              3
# url              1705
# file             1705
# file-name        1704
# lic                 8
# q                   5
# length            162
# time              541
# date             1016
# uploaded          930
# also              328
# rmk               568
# bird-seen           3
# animal-seen         3
# playback-used       3
# temp                0
# regnr               0
# auto                3
# dvc                39
# mic                31
# smp                 8
# sono.small       1705
# sono.med         1705
# sono.large       1705
# sono.full        1705
# osci.small       1705
# osci.med         1705
# osci.large       1705
# file-path        1704
# dtype: int64

# %%
file_path_data = data[["file-name","file-path"]]
file_path_data.head()
# Out:
#                                            file-name
# 0  XC794616_TRITOT_2023_04_20_10_31_TORPVIKEN_s_A...  \
# 1                            XC794247_ZOOM0001to.wav
# 2         XC793904_Redshank_2121_160423_filtered.mp3
# 3                        XC793224_RK_HD389B_1.50.wav
# 4            XC792814_230409_gambette_type_chant.mp3
#
#                                            file-path
# 0  data/audio/XC794616_TRITOT_2023_04_20_10_31_TO...
# 1                 data/audio/XC794247_ZOOM0001to.wav
# 2  data/audio/XC793904_Redshank_2121_160423_filte...
# 3             data/audio/XC793224_RK_HD389B_1.50.wav
# 4  data/audio/XC792814_230409_gambette_type_chant...

# %%
import seaborn as sns

# ax = pd.crosstab(data.en,data.cnt).plot(kind='bar', figsize=(20,10))
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
sns.scatterplot(data, x="lng", y="lat", hue="en")
# Out:
# <Axes: xlabel='lng', ylabel='lat'>

# %%
# ax = pd.crosstab(data.en,data.type).plot(kind='bar', figsize=(20,10))
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data.sex).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data.stage).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.stage,data.sex).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data.method).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data.q).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# ax = pd.crosstab(data.en,data.length).plot(kind='bar', figsize=(20,10))
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
# ax = pd.crosstab(data.en,data.also).plot(kind='bar', figsize=(20,10))
# for p in ax.patches:
#     ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data["playback-used"]).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.mic,data.dvc).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data.dvc).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
ax = pd.crosstab(data.en,data.mic).plot(kind='bar', figsize=(20,10))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
import matplotlib.pyplot as plt
categorical = data.select_dtypes(include = ['object'])
categorical_cols = list(set(categorical.columns))

fig, axes = plt.subplots(nrows=(len(categorical_cols)//2)+(len(categorical_cols)%2), ncols=2,figsize=(25,500))
for idx, feat in enumerate(categorical_cols):
    ax = axes[int(idx/2), idx%2]
    sns.countplot(x=feat, data=categorical,ax=ax);
    
for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=90)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705 entries, 0 to 1704
# Data columns (total 44 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1705 non-null   int64
#  1   gen            1705 non-null   object
#  2   sp             1705 non-null   object
#  3   ssp            162 non-null    object
#  4   group          1705 non-null   object
#  5   en             1705 non-null   object
#  6   rec            1705 non-null   object
#  7   cnt            1705 non-null   object
#  8   loc            1704 non-null   object
#  9   lat            1694 non-null   float64
#  10  lng            1694 non-null   float64
#  11  alt            1661 non-null   object
#  12  type           1691 non-null   object
#  13  sex            293 non-null    object
#  14  stage          259 non-null    object
#  15  method         1705 non-null   object
#  16  url            1705 non-null   object
#  17  file           1705 non-null   object
#  18  file-name      1705 non-null   object
#  19  lic            1705 non-null   object
#  20  q              1705 non-null   object
#  21  length         1705 non-null   object
#  22  time           1705 non-null   object
#  23  date           1705 non-null   object
#  24  uploaded       1705 non-null   object
#  25  also           1705 non-null   object
#  26  rmk            780 non-null    object
#  27  bird-seen      1705 non-null   object
#  28  animal-seen    1705 non-null   object
#  29  playback-used  1705 non-null   object
#  30  temp           0 non-null      float64
#  31  regnr          0 non-null      float64
#  32  auto           1705 non-null   object
#  33  dvc            108 non-null    object
#  34  mic            69 non-null     object
#  35  smp            1705 non-null   int64
#  36  sono.small     1705 non-null   object
#  37  sono.med       1705 non-null   object
#  38  sono.large     1705 non-null   object
#  39  sono.full      1705 non-null   object
#  40  osci.small     1705 non-null   object
#  41  osci.med       1705 non-null   object
#  42  osci.large     1705 non-null   object
#  43  file-path      1705 non-null   object
# dtypes: float64(4), int64(2), object(38)
# memory usage: 586.2+ KB

# %%
numeric_data = data.select_dtypes(['int64','float64'])

# %%
numeric_data.corr('pearson')
# Out:
#              id       lat       lng  temp  regnr       smp
# id     1.000000  0.156872 -0.235959   NaN    NaN -0.031644
# lat    0.156872  1.000000 -0.797265   NaN    NaN -0.002397
# lng   -0.235959 -0.797265  1.000000   NaN    NaN -0.010623
# temp        NaN       NaN       NaN   NaN    NaN       NaN
# regnr       NaN       NaN       NaN   NaN    NaN       NaN
# smp   -0.031644 -0.002397 -0.010623   NaN    NaN  1.000000

# %%
numeric_data.corr('spearman')
# Out:
#              id       lat       lng  temp  regnr       smp
# id     1.000000  0.063701 -0.238145   NaN    NaN -0.057971
# lat    0.063701  1.000000 -0.512122   NaN    NaN  0.070389
# lng   -0.238145 -0.512122  1.000000   NaN    NaN -0.022429
# temp        NaN       NaN       NaN   NaN    NaN       NaN
# regnr       NaN       NaN       NaN   NaN    NaN       NaN
# smp   -0.057971  0.070389 -0.022429   NaN    NaN  1.000000

# %%
numeric_data.corr('kendall')
# Out:
#              id       lat       lng  temp  regnr       smp
# id     1.000000  0.043097 -0.165389   NaN    NaN -0.045750
# lat    0.043097  1.000000 -0.325382   NaN    NaN  0.056189
# lng   -0.165389 -0.325382  1.000000   NaN    NaN -0.017304
# temp        NaN       NaN       NaN   NaN    NaN       NaN
# regnr       NaN       NaN       NaN   NaN    NaN       NaN
# smp   -0.045750  0.056189 -0.017304   NaN    NaN  1.000000
